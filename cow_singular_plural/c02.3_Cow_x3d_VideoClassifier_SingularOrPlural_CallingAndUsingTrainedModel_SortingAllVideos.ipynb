# %%
# !pip install pytorchvideo torchvision av
# Out:
# Collecting pytorchvideo
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.26.0+cu128)
# Collecting av
#   Downloading av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting fvcore (from pytorchvideo)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting parameterized (from pytorchvideo)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pytorchvideo) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.11.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->torchvision) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->pytorchvideo) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fvcore->pytorchvideo) (4.67.3)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->pytorchvideo) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore->pytorchvideo) (0.9.0)
# Collecting portalocker (from iopath->pytorchvideo)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0->torchvision) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.11.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.11.0->torchvision) (3.0.3)
# Downloading av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 67.4 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188686 sha256=5c7c0a92d2fd41dfad97d1cf3bf324555e07db8aa9dc50a8a8f4bd9bf09290ee
#   Stored in directory: /root/.cache/pip/wheels/b3/49/dc/aab2dce83e38b59849db13a4f4ddd220e568e24b58332fb0f9
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=d45d677e84e2d0c5416a97865571a7bb913c3767fbbf28612174a13e9d9c94f9
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=d3d4dd8bc7623122be440b166d96ca195b638739391c729d263e36c95ce5f1bb
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, portalocker, parameterized, av, iopath, fvcore, pytorchvideo
# Successfully installed av-17.1.0 fvcore-0.1.5.post20221221 iopath-0.1.10 parameterized-0.9.0 portalocker-3.2.0 pytorchvideo-0.1.5 yacs-0.1.8

# %%
# --- 0. THE PYTORCHVIDEO BUG FIX (Monkey Patch) ---
import sys
import torchvision.transforms.functional as F_vision
sys.modules['torchvision.transforms.functional_tensor'] = F_vision

# --- 1. IMPORTS ---
import os
import shutil
import torch
import torch.nn as nn
import torch.nn.functional as F
from google.colab import drive

from torchvision.transforms import Compose, Lambda, Resize
from torchvision.transforms._transforms_video import NormalizeVideo
from pytorchvideo.transforms import ApplyTransformToKey, UniformTemporalSubsample
from pytorchvideo.data.encoded_video import EncodedVideo

# --- 2. CONFIGURATION ---
# Connect to Google Drive
drive.mount('/content/drive', force_remount=True)

CLASSES = ['cow_singular', 'cow_plural']
NUM_FRAMES = 16  # X3D defaults to 16 frames
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- THE MAGIC THRESHOLD ---
# Anything below 60% confidence gets sorted into Miscellaneous
THRESHOLD = 0.60

# The Paths
# Updated to match the X3D model name we saved during training
MODEL_WEIGHTS_PATH = "/content/drive/MyDrive/Trained_Models/cow_x3d_singular_plural_TrainedModel.pth"
TEST_FOLDER_PATH = "/content/drive/MyDrive/cow_data/cow_data_all"
RESULT_FOLDER_PATH = "/content/drive/MyDrive/Result"

# Mapping the guesses to your folders (Added the Miscellaneous bucket!)
BUCKET_NAMES = {
    'cow_singular': 'Predicted_cow_singular',
    'cow_plural': 'Predicted_cow_plural',
    'miscellaneous': 'Predicted_Miscellaneous'
}

# --- 3. BUILD THE ROBOT BODY & LOAD THE BRAIN ---
print("Building the robot (X3D-M) and loading the brain...")
model = torch.hub.load('facebookresearch/pytorchvideo', 'x3d_m', pretrained=False)

# Change the head so it knows we only have 2 classes
in_features = model.blocks[5].proj.in_features
model.blocks[5].proj = nn.Linear(in_features, len(CLASSES))

model.load_state_dict(torch.load(MODEL_WEIGHTS_PATH, map_location=DEVICE))
model = model.to(DEVICE)
model.eval()

# --- 4. VIDEO GLASSES (TRANSFORMS) ---
video_transform = Compose([
    ApplyTransformToKey(
        key="video",
        transform=Compose([
            UniformTemporalSubsample(NUM_FRAMES),
            Lambda(lambda x: x / 255.0),
            NormalizeVideo(mean=[0.45, 0.45, 0.45], std=[0.225, 0.225, 0.225]), # X3D specifics
            Resize((256, 256)) # X3D specifics
        ])
    )
])

# --- 5. THE SORTING LOOP ---
print(f"\n--- STARTING THE SORTING MACHINE (Threshold: {THRESHOLD*100}%) ---")

# Look at every single file inside the test folder
for filename in os.listdir(TEST_FOLDER_PATH):

    # Only look at video files, ignore random hidden files
    if not filename.lower().endswith(('.mp4', '.avi', '.mov')):
        continue

    video_path = os.path.join(TEST_FOLDER_PATH, filename)
    print(f"\nWatching: {filename}...")

    try:
        # Load the 2-second clip and put the glasses on it
        video = EncodedVideo.from_path(video_path)
        video_data = video.get_clip(start_sec=0.0, end_sec=2.0)
        video_data = video_transform(video_data)
        input_tensor = video_data["video"].unsqueeze(0).to(DEVICE)

        # Make the guess!
        with torch.no_grad():
            output = model(input_tensor)
            probs = F.softmax(output, dim=1)
            conf, pred_idx = torch.max(probs, 1)

        # --- THE MISCELLANEOUS INTERCEPT ---
        confidence_score = conf.item()
        original_guess = CLASSES[pred_idx.item()]

        if confidence_score < THRESHOLD:
            winning_guess = 'miscellaneous'
            print(f"Guess: MISCELLANEOUS (Unsure about {original_guess.upper()}, only {confidence_score*100:.2f}% sure)")
        else:
            winning_guess = original_guess
            print(f"Guess: {winning_guess.upper()} ({confidence_score*100:.2f}% sure)")

        # --- THE FILE MOVING MAGIC ---
        # Look up the exact folder name from your dictionary
        target_bucket = BUCKET_NAMES[winning_guess]

        # Build the paths
        target_folder = os.path.join(RESULT_FOLDER_PATH, target_bucket)
        target_path = os.path.join(target_folder, filename)

        # ⭐️ IMPORTANT: Make sure the folder exists!
        # If 'Predicted_Miscellaneous' isn't in your drive yet, this line creates it automatically.
        os.makedirs(target_folder, exist_ok=True)

        # Copy the video into your folder!
        shutil.copy(video_path, target_path)
        print(f"-> Safely copied into {target_bucket}!")

    except Exception as e:
        print(f"Oh no! Something went wrong with {filename}: {e}")

print("\n--- ALL DONE! CHECK YOUR RESULT FOLDERS! ---")
# Out:
# Mounted at /content/drive
# Building the robot (X3D-M) and loading the brain...
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# --- STARTING THE SORTING MACHINE (Threshold: 60.0%) ---
#
# Watching: apr18_t0008_f012085.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013022.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012469.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012158.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012222.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012041.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012390.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012857.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012255.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012188.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012717.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012353.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012010.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012927.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 55.83% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0008_f012621.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012809.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012652.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012425.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f012687.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013626.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014019.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013459.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013557.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014101.mp4...
# Guess: COW_SINGULAR (70.51% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013812.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013890.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013923.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013296.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013184.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013512.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013676.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013115.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013067.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013587.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013148.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013765.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013390.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013859.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013342.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014139.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014065.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013426.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013243.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013725.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f013971.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014547.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014397.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014905.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014471.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015243.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015213.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014817.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015303.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014173.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014583.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015385.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014941.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015128.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f014624.mp4...
# Guess: COW_SINGULAR (73.11% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr18_t0008_f015060.mp4...
